# %%
# import libraries
import torch
import numpy as np

# %%
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler

# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 20
# percentage of training set to use as validation
valid_size = 0.2

# convert data to torch.FloatTensor
transform = transforms.ToTensor()

# choose the training and test datasets
train_data = datasets.MNIST(root='data', train=True,
                                   download=True, transform=transform)
test_data = datasets.MNIST(root='data', train=False,
                                  download=True, transform=transform)

# obtain training indices that will be used for validation
num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
    sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, 
    sampler=valid_sampler, num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, 
    num_workers=num_workers)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
    
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy()

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    # print out the correct label for each image
    # .item() gets the value contained in a Tensor
    ax.set_title(str(labels[idx].item()))

# %%
import torch.nn as nn
import torch.nn.functional as F

# define the NN architecture
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        # number of hidden nodes in each layer (512)
        hidden_1 = 512
        hidden_2 = 512
        # linear layer (784 -> hidden_1)
        self.fc1 = nn.Linear(28 * 28, hidden_1)
        # linear layer (n_hidden -> hidden_2)
        self.fc2 = nn.Linear(hidden_1, hidden_2)
        # linear layer (n_hidden -> 10)
        self.fc3 = nn.Linear(hidden_2, 10)
        # dropout layer (p=0.2)
        # dropout prevents overfitting of data
        self.dropout = nn.Dropout(0.2)

    def forward(self, x):
        # flatten image input
        x = x.view(-1, 28 * 28)
        # add hidden layer, with relu activation function
        x = F.relu(self.fc1(x))
        # add dropout layer
        x = self.dropout(x)
        # add hidden layer, with relu activation function
        x = F.relu(self.fc2(x))
        # add dropout layer
        x = self.dropout(x)
        # add output layer
        x = self.fc3(x)
        return x

# initialize the NN
model = Net()
print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=10, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
# specify loss function (categorical cross-entropy)
criterion = nn.CrossEntropyLoss()

# specify optimizer (stochastic gradient descent) and learning rate = 0.01
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# %%
# number of epochs to train the model
n_epochs = 50

# initialize tracker for minimum validation loss
valid_loss_min = np.Inf # set initial "min" to infinity

for epoch in range(n_epochs):
    # monitor training loss
    train_loss = 0.0
    valid_loss = 0.0
    
    ###################
    # train the model #
    ###################
    model.train() # prep model for training
    for data, target in train_loader:
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()
        
    ######################    
    # validate the model #
    ######################
    model.eval() # prep model for evaluation
    for data, target in valid_loader:
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # update running validation loss 
        valid_loss += loss.item()
        
    # print training/validation statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader)
    valid_loss = valid_loss/len(valid_loader)
    
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch+1, 
        train_loss,
        valid_loss
        ))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model.state_dict(), 'model.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 0.942461 	Validation Loss: 0.389030
# Validation loss decreased (inf --> 0.389030).  Saving model ...
# Epoch: 2 	Training Loss: 0.357169 	Validation Loss: 0.295269
# Validation loss decreased (0.389030 --> 0.295269).  Saving model ...
# Epoch: 3 	Training Loss: 0.282224 	Validation Loss: 0.245103
# Validation loss decreased (0.295269 --> 0.245103).  Saving model ...
# Epoch: 4 	Training Loss: 0.232605 	Validation Loss: 0.207423
# Validation loss decreased (0.245103 --> 0.207423).  Saving model ...
# Epoch: 5 	Training Loss: 0.199002 	Validation Loss: 0.178568
# Validation loss decreased (0.207423 --> 0.178568).  Saving model ...
# Epoch: 6 	Training Loss: 0.173301 	Validation Loss: 0.158484
# Validation loss decreased (0.178568 --> 0.158484).  Saving model ...
# Epoch: 7 	Training Loss: 0.151555 	Validation Loss: 0.145375
# Validation loss decreased (0.158484 --> 0.145375).  Saving model ...
# Epoch: 8 	Training Loss: 0.136295 	Validation Loss: 0.132737
# Validation loss decreased (0.145375 --> 0.132737).  Saving model ...
# Epoch: 9 	Training Loss: 0.122027 	Validation Loss: 0.121829
# Validation loss decreased (0.132737 --> 0.121829).  Saving model ...
# Epoch: 10 	Training Loss: 0.112604 	Validation Loss: 0.114590
# Validation loss decreased (0.121829 --> 0.114590).  Saving model ...
# Epoch: 11 	Training Loss: 0.102766 	Validation Loss: 0.108525
# Validation loss decreased (0.114590 --> 0.108525).  Saving model ...
# Epoch: 12 	Training Loss: 0.093951 	Validation Loss: 0.102991
# Validation loss decreased (0.108525 --> 0.102991).  Saving model ...
# Epoch: 13 	Training Loss: 0.086973 	Validation Loss: 0.096414
# Validation loss decreased (0.102991 --> 0.096414).  Saving model ...
# Epoch: 14 	Training Loss: 0.081141 	Validation Loss: 0.094793
# Validation loss decreased (0.096414 --> 0.094793).  Saving model ...
# Epoch: 15 	Training Loss: 0.075917 	Validation Loss: 0.090591
# Validation loss decreased (0.094793 --> 0.090591).  Saving model ...
# Epoch: 16 	Training Loss: 0.070223 	Validation Loss: 0.086934
# Validation loss decreased (0.090591 --> 0.086934).  Saving model ...
# Epoch: 17 	Training Loss: 0.064605 	Validation Loss: 0.085380
# Validation loss decreased (0.086934 --> 0.085380).  Saving model ...
# Epoch: 18 	Training Loss: 0.061941 	Validation Loss: 0.083830
# Validation loss decreased (0.085380 --> 0.083830).  Saving model ...
# Epoch: 19 	Training Loss: 0.059024 	Validation Loss: 0.079869
# Validation loss decreased (0.083830 --> 0.079869).  Saving model ...
# Epoch: 20 	Training Loss: 0.053360 	Validation Loss: 0.079178
# Validation loss decreased (0.079869 --> 0.079178).  Saving model ...
# Epoch: 21 	Training Loss: 0.051562 	Validation Loss: 0.077615
# Validation loss decreased (0.079178 --> 0.077615).  Saving model ...
# Epoch: 22 	Training Loss: 0.048121 	Validation Loss: 0.073434
# Validation loss decreased (0.077615 --> 0.073434).  Saving model ...
# Epoch: 23 	Training Loss: 0.045858 	Validation Loss: 0.074039
# Epoch: 24 	Training Loss: 0.043069 	Validation Loss: 0.072340
# Validation loss decreased (0.073434 --> 0.072340).  Saving model ...
# Epoch: 25 	Training Loss: 0.039847 	Validation Loss: 0.070785
# Validation loss decreased (0.072340 --> 0.070785).  Saving model ...
# Epoch: 26 	Training Loss: 0.039116 	Validation Loss: 0.070703
# Validation loss decreased (0.070785 --> 0.070703).  Saving model ...
# Epoch: 27 	Training Loss: 0.036527 	Validation Loss: 0.069390
# Validation loss decreased (0.070703 --> 0.069390).  Saving model ...
# Epoch: 28 	Training Loss: 0.034552 	Validation Loss: 0.070081
# Epoch: 29 	Training Loss: 0.033065 	Validation Loss: 0.068356
# Validation loss decreased (0.069390 --> 0.068356).  Saving model ...
# Epoch: 30 	Training Loss: 0.031114 	Validation Loss: 0.068715
# Epoch: 31 	Training Loss: 0.030594 	Validation Loss: 0.067373
# Validation loss decreased (0.068356 --> 0.067373).  Saving model ...
# Epoch: 32 	Training Loss: 0.028382 	Validation Loss: 0.067685
# Epoch: 33 	Training Loss: 0.028010 	Validation Loss: 0.066206
# Validation loss decreased (0.067373 --> 0.066206).  Saving model ...
# Epoch: 34 	Training Loss: 0.025075 	Validation Loss: 0.067937
# Epoch: 35 	Training Loss: 0.024634 	Validation Loss: 0.067171
# Epoch: 36 	Training Loss: 0.023194 	Validation Loss: 0.065940
# Validation loss decreased (0.066206 --> 0.065940).  Saving model ...
# Epoch: 37 	Training Loss: 0.022805 	Validation Loss: 0.065582
# Validation loss decreased (0.065940 --> 0.065582).  Saving model ...
# Epoch: 38 	Training Loss: 0.020925 	Validation Loss: 0.066192
# Epoch: 39 	Training Loss: 0.020136 	Validation Loss: 0.063926
# Validation loss decreased (0.065582 --> 0.063926).  Saving model ...
# Epoch: 40 	Training Loss: 0.019384 	Validation Loss: 0.064714
# Epoch: 41 	Training Loss: 0.018254 	Validation Loss: 0.064988
# Epoch: 42 	Training Loss: 0.018237 	Validation Loss: 0.066020
# Epoch: 43 	Training Loss: 0.017377 	Validation Loss: 0.064444
# Epoch: 44 	Training Loss: 0.015825 	Validation Loss: 0.065440
# Epoch: 45 	Training Loss: 0.016316 	Validation Loss: 0.064548
# Epoch: 46 	Training Loss: 0.015450 	Validation Loss: 0.063861
# Validation loss decreased (0.063926 --> 0.063861).  Saving model ...
# Epoch: 47 	Training Loss: 0.014050 	Validation Loss: 0.064799
# Epoch: 48 	Training Loss: 0.014315 	Validation Loss: 0.063230
# Validation loss decreased (0.063861 --> 0.063230).  Saving model ...
# Epoch: 49 	Training Loss: 0.013874 	Validation Loss: 0.063559
# Epoch: 50 	Training Loss: 0.012940 	Validation Loss: 0.064712

# %%
# Load the Model with the Lowest Validation Loss
model.load_state_dict(torch.load('model.pt'))
# Out:
# <All keys matched successfully>

# %%
# initialize lists to monitor test loss and accuracy
test_loss = 0.0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

model.eval() # prep model for evaluation

for data, target in test_loader:
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data)
    # calculate the loss
    loss = criterion(output, target)
    # update test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)
    # compare predictions to true label
    correct = np.squeeze(pred.eq(target.data.view_as(pred)))
    # calculate test accuracy for each object class
    for i in range(batch_size):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# calculate and print avg test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            str(i), 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.059733
#
# Test Accuracy of     0: 98% (968/980)
# Test Accuracy of     1: 99% (1125/1135)
# Test Accuracy of     2: 98% (1014/1032)
# Test Accuracy of     3: 98% (997/1010)
# Test Accuracy of     4: 98% (967/982)
# Test Accuracy of     5: 97% (872/892)
# Test Accuracy of     6: 97% (938/958)
# Test Accuracy of     7: 97% (1004/1028)
# Test Accuracy of     8: 97% (948/974)
# Test Accuracy of     9: 96% (978/1009)
#
# Test Accuracy (Overall): 98% (9811/10000)

# %%
# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = dataiter.next()

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds = torch.max(output, 1)
# prep images for display
images = images.numpy()

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    ax.set_title("{} ({})".format(str(preds[idx].item()), str(labels[idx].item())),
                 color=("green" if preds[idx]==labels[idx] else "red"))
